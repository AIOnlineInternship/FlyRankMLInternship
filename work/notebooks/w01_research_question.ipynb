# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AIOnlineInternship/FlyRankMLInternship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# I chose this lane because content decay is a universal problem for publishers.
# Rather than guessing which pages to update,
# applying machine learning to historical
# performance (like traffic drops, CTR, and impressions)
# can help prioritize the most promising pages.
# This maximizes the ROI of editorial effort by
# focusing on content that is likely to
# recover and drive significant traffic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# **Decision:** Which decaying or underperforming content should be prioritized for an update?
#
# **Action:** The editorial team revises, expands, or refreshes the flagged articles.
#
# **Cost of a wrong call:** Wasting expensive editorial hours on content that won't recover its rank/traffic, while leaving potentially high-reward pages untouched (opportunity cost).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# I loaded the 30,000-row starter CSV file to understand the scale of the problem.
#
# - There are exactly **30,000** content items.
#
# - Over **30%** of the pages have a "down" trend direction.
#
# - The average page has around **1,500** clicks over the 90-day window.
# This shows a substantial pool of declining pages where prioritization is needed.
#
# See the below cell for code.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
total_rows = len(df)
declining_count = len(df[df['trend_direction'] == 'down'])

print(f"Total rows: {total_rows:,}")
print(f"Declining pages: {declining_count:,} ({declining_count/total_rows:.1%})")
print(f"Average clicks (90d): {df['clicks_90d'].mean():,.0f}")
# Out:
# Total rows: 30,000
# Declining pages: 16,262 (54.2%)
# Average clicks (90d): 16

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# Based on the data and experiementation, **What I can claim:**
# - The model provides a *directional* score for prioritizing content
#   refreshes based on observed historical patterns.
# - It is a *decision-support* tool to help editors allocate their time more effectively.
#
# **What I can't claim:**
# - I cannot claim *causal proof* that an update will absolutely result in improved traffic.
# - The model is not *'predicting Google'* or reverse-engineering search algorithms.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
